# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\morsh\anaconda3\envs\myenv\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\morsh\anaconda3\envs\myenv\lib\site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.10.23-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\morsh\anaconda3\envs\myenv\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 39.1 MB/s eta 0:00:00
# Downloading regex-2025.10.23-cp310-cp310-win_amd64.whl (277 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed nltk-3.9.2 regex-2025.10.23 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\morsh\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'C:\Users\morsh\anaconda3\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
corpus="""Hello Welcome, to Morshadul Alam's NLP Exercises.
Please do practice the entire course! to become an expert in NLP. 
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Morshadul Alam's NLP Exercises.
# Please do practice the entire course! to become an expert in NLP.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
documents=sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\morsh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Morshadul Alam's NLP Exercises.
# Please do practice the entire course!
# to become an expert in NLP.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Morshadul',
#  'Alam',
#  "'s",
#  'NLP',
#  'Exercises',
#  '.',
#  'Please',
#  'do',
#  'practice',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Morshadul', 'Alam', "'s", 'NLP', 'Exercises', '.']
# ['Please', 'do', 'practice', 'the', 'entire', 'course', '!']
# ['to', 'become', 'an', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Morshadul',
#  'Alam',
#  "'",
#  's',
#  'NLP',
#  'Exercises',
#  '.',
#  'Please',
#  'do',
#  'practice',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Morshadul',
#  'Alam',
#  "'s",
#  'NLP',
#  'Exercises.',
#  'Please',
#  'do',
#  'practice',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']
